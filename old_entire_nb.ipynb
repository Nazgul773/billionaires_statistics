# %% [markdown]
# # Imports and reading Data

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
# import geopandas as gpd
# import plotly.express as px
import matplotlib.patches as mpatches

# %%
base_dir = os.getcwd()
data_dir = os.path.join(base_dir, 'data')
sns.set_theme(style="darkgrid")
#plt.style.use('ggplot')

# %%
df = pd.read_csv(os.path.join(data_dir, 'Billionaires Statistics Dataset.csv'))
df
# Out:
#       rank  finalWorth               category                personName   age  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1        2      180000             Automotive                 Elon Musk  51.0
# 2        3      114000             Technology                Jeff Bezos  59.0
# 3        4      107000             Technology             Larry Ellison  78.0
# 4        5      106000  Finance & Investments            Warren Buffett  92.0
# ...    ...         ...                    ...                       ...   ...
# 2635  2540        1000             Healthcare                   Yu Rong  51.0
# 2636  2540        1000        Food & Beverage    Richard Yuengling, Jr.  80.0
# 2637  2540        1000          Manufacturing             Zhang Gongyun  60.0
# 2638  2540        1000            Real Estate    Zhang Guiping & family  71.0
# 2639  2540        1000            Diversified               Inigo Zobel  66.0
#
# ...

# %% [markdown]
# # Data Understanding

# %%
df.shape
# Out:
# (2640, 35)

# %%
df.head(10)
# Out:
#    rank  finalWorth               category                 personName   age  \
# 0     1      211000       Fashion & Retail   Bernard Arnault & family  74.0
# 1     2      180000             Automotive                  Elon Musk  51.0
# 2     3      114000             Technology                 Jeff Bezos  59.0
# 3     4      107000             Technology              Larry Ellison  78.0
# 4     5      106000  Finance & Investments             Warren Buffett  92.0
# 5     6      104000             Technology                 Bill Gates  67.0
# 6     7       94500  Media & Entertainment          Michael Bloomberg  81.0
# 7     8       93000                Telecom  Carlos Slim Helu & family  83.0
# 8     9       83400            Diversified              Mukesh Ambani  65.0
# 9    10       80700             Technology              Steve Ballmer  67.0
#
#          country         city              source             industries  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2640 entries, 0 to 2639
# Data columns (total 35 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   rank                                        2640 non-null   int64
#  1   finalWorth                                  2640 non-null   int64
#  2   category                                    2640 non-null   object
#  3   personName                                  2640 non-null   object
#  4   age                                         2575 non-null   float64
#  5   country                                     2602 non-null   object
#  6   city                                        2568 non-null   object
#  7   source                                      2640 non-null   object
#  8   industries                                  2640 non-null   object
#  9   countryOfCitizenship                        2640 non-null   object
# ...

# %%
df.describe()
# Out:
#               rank     finalWorth          age    birthYear   birthMonth  \
# count  2640.000000    2640.000000  2575.000000  2564.000000  2564.000000
# mean   1289.159091    4623.787879    65.140194  1957.183307     5.740250
# std     739.693726    9834.240939    13.258098    13.282516     3.710085
# min       1.000000    1000.000000    18.000000  1921.000000     1.000000
# 25%     659.000000    1500.000000    56.000000  1948.000000     2.000000
# 50%    1312.000000    2300.000000    65.000000  1957.000000     6.000000
# 75%    1905.000000    4200.000000    75.000000  1966.000000     9.000000
# max    2540.000000  211000.000000   101.000000  2004.000000    12.000000
#
#           birthDay  cpi_country  cpi_change_country  \
# count  2564.000000  2456.000000         2456.000000
# mean     12.099844   127.755204            4.364169
# std       9.918876    26.452951            3.623763
# min       1.000000    99.550000           -1.900000
# ...

# %% [markdown]
# # Data Preparation

# %%
df = df[['rank', 'finalWorth', 'personName',
         #   'source', 'countryOfCitizenship', 'organization','lastName', 'firstName',
         'age', 'country', 'city', 'industries',
         'selfMade', 'status', 'gender',
         #'birthDate', 'title', 'state', 'residenceStateRegion', 'birthYear', 'date', 'category'
         #'birthMonth', 'birthDay', 'cpi_country', 'cpi_change_country',
         'life_expectancy_country',
         #'tax_revenue_country_country',
         #'latitude_country', 'longitude_country'
         'gross_tertiary_education_enrollment', 'gross_primary_education_enrollment_country',
         'gdp_country', 'total_tax_rate_country', 'population_country'
         ]].copy()

# %%
df.shape
# Out:
# (2640, 16)

# %%
df.columns
# Out:
# Index(['rank', 'finalWorth', 'personName', 'age', 'country', 'city',
#        'industries', 'selfMade', 'status', 'gender', 'life_expectancy_country',
#        'gross_tertiary_education_enrollment',
#        'gross_primary_education_enrollment_country', 'gdp_country',
#        'total_tax_rate_country', 'population_country'],
#       dtype='object')

# %%
df.rename(columns={'personName': 'person_name', 'finalWorth': 'final_worth', 'selfMade': 'wealth_source',
                   'gdp_country': 'gdp_country_in_dollars',
                   'gross_tertiary_education_enrollment': 'gross_tertiary_education_enrollment_country'}, inplace=True)

# %%
replace_dict = {True: 'Self-Made',
                False: 'Inherited/Unearned'}
df['wealth_source'].replace(replace_dict, inplace=True)
# Out:
# C:\Users\benne\AppData\Local\Temp\ipykernel_18108\1749480833.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['wealth_source'].replace(replace_dict, inplace=True)

# %%
df['gdp_country_in_dollars'] = pd.to_numeric(df['gdp_country_in_dollars'].str.strip('$ ').str.replace(',', ''))

# %%
df
# Out:
#       rank  final_worth               person_name   age        country  \
# 0        1       211000  Bernard Arnault & family  74.0         France
# 1        2       180000                 Elon Musk  51.0  United States
# 2        3       114000                Jeff Bezos  59.0  United States
# 3        4       107000             Larry Ellison  78.0  United States
# 4        5       106000            Warren Buffett  92.0  United States
# ...    ...          ...                       ...   ...            ...
# 2635  2540         1000                   Yu Rong  51.0          China
# 2636  2540         1000    Richard Yuengling, Jr.  80.0  United States
# 2637  2540         1000             Zhang Gongyun  60.0          China
# 2638  2540         1000    Zhang Guiping & family  71.0          China
# 2639  2540         1000               Inigo Zobel  66.0    Philippines
#
#             city             industries       wealth_source status gender  \
# ...

# %%
df.isna().sum()
# Out:
# rank                                             0
# final_worth                                      0
# person_name                                      0
# age                                             65
# country                                         38
# city                                            72
# industries                                       0
# wealth_source                                    0
# status                                           0
# gender                                           0
# life_expectancy_country                        182
# gross_tertiary_education_enrollment_country    182
# gross_primary_education_enrollment_country     181
# gdp_country_in_dollars                         164
# total_tax_rate_country                         182
# population_country                             164
# dtype: int64

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [rank, final_worth, person_name, age, country, city, industries, wealth_source, status, gender, life_expectancy_country, gross_tertiary_education_enrollment_country, gross_primary_education_enrollment_country, gdp_country_in_dollars, total_tax_rate_country, population_country]
# Index: []

# %%
df.loc[df.duplicated(subset=['person_name', 'country'])]
# Out:
#       rank  final_worth            person_name   age country      city  \
# 2112  2020         1400  Wang Yanqing & family  76.0   China    Weihai
# 2317  2259         1200                  Li Li  59.0   China  Shenzhen
#
#          industries       wealth_source status gender  \
# 2112  Manufacturing  Inherited/Unearned      D      F
# 2317     Healthcare           Self-Made      D      M
#
#       life_expectancy_country  gross_tertiary_education_enrollment_country  \
# 2112                     77.0                                         50.6
# 2317                     77.0                                         50.6
#
#       gross_primary_education_enrollment_country  gdp_country_in_dollars  \
# 2112                                       100.2            1.991000e+13
# 2317                                       100.2            1.991000e+13
#
#       total_tax_rate_country  population_country
# 2112                    59.2        1.397715e+09
# ...

# %%
df.query('person_name == "Li Li" or person_name.str.startswith("Wang Yanqing")')
# Out:
#       rank  final_worth            person_name   age country      city  \
# 785    766         3700  Wang Yanqing & family  56.0   China      Wuxi
# 1045  1027         2900                  Li Li  57.0   China  Changsha
# 2112  2020         1400  Wang Yanqing & family  76.0   China    Weihai
# 2317  2259         1200                  Li Li  59.0   China  Shenzhen
#
#          industries       wealth_source status gender  \
# 785   Manufacturing           Self-Made      D      M
# 1045     Healthcare           Self-Made      U      M
# 2112  Manufacturing  Inherited/Unearned      D      F
# 2317     Healthcare           Self-Made      D      M
#
#       life_expectancy_country  gross_tertiary_education_enrollment_country  \
# 785                      77.0                                         50.6
# 1045                     77.0                                         50.6
# 2112                     77.0                                         50.6
# ...

# %%
df = df.loc[~df.duplicated(subset=['person_name', 'country'])] \
    .reset_index(drop=True).copy()

# %%
df.query('person_name == "Li Li" or person_name.str.startswith("Wang Yanqing")')
# Out:
#       rank  final_worth            person_name   age country      city  \
# 785    766         3700  Wang Yanqing & family  56.0   China      Wuxi
# 1045  1027         2900                  Li Li  57.0   China  Changsha
#
#          industries wealth_source status gender  life_expectancy_country  \
# 785   Manufacturing     Self-Made      D      M                     77.0
# 1045     Healthcare     Self-Made      U      M                     77.0
#
#       gross_tertiary_education_enrollment_country  \
# 785                                          50.6
# 1045                                         50.6
#
#       gross_primary_education_enrollment_country  gdp_country_in_dollars  \
# 785                                        100.2            1.991000e+13
# 1045                                       100.2            1.991000e+13
#
#       total_tax_rate_country  population_country
# 785                     59.2        1.397715e+09
# 1045                    59.2        1.397715e+09

# %% [markdown]
# # Feature Understanding

# %%
df['age'].value_counts()
# Out:
# age
# 60.0     88
# 58.0     83
# 59.0     81
# 57.0     75
# 66.0     74
#          ..
# 20.0      1
# 19.0      1
# 18.0      1
# 101.0     1
# 28.0      1
# Name: count, Length: 79, dtype: int64

# %%
country_counts = df['country'].value_counts().head(10)
ax = country_counts.plot(kind='bar',
                         figsize=(10, 5))
plt.title('Top 10 Countries Worldwide Absolute Billionaire Distribution',
          fontsize=18,
          fontweight='bold',
          y=1.02)
ax.set_ylabel('Count')
ax.set_xlabel('Country')
for i, count in enumerate(country_counts):
    plt.text(i, count + 1, str(count), ha='center', va='bottom')
plt.savefig('media/univariate_analysis/Top_10_Countries_Worldwide_Absolute_Billionaire_Distribution.png',
            bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 12
#      10 for i, count in enumerate(country_counts):
#      11     plt.text(i, count + 1, str(count), ha='center', va='bottom')
# ---> 12 plt.savefig('media/univariate_analysis/Top_10_Countries_Worldwide_Absolute_Billionaire_Distribution.png',
#      13             bbox_inches='tight')
#      14 plt.show()
#
# File ~\PycharmProjects\billionaires_statistics\venv\lib\site-packages\matplotlib\pyplot.py:1119, in savefig(*args, **kwargs)
#    1116 fig = gcf()
#    1117 # savefig default implementation has no return, so mypy is unhappy
#    1118 # presumably this is here because subclasses can return?
# -> 1119 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1120 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1121 return res
#
# ...

# %%
city_counts = df['city'].value_counts() \
    .head(10)
ax = city_counts.plot(kind='bar',
                      figsize=(10, 5))
plt.title("Top 10 Cities Worldwide Absolute Billionaire Distribution",
          fontsize=18,
          fontweight='bold',
          y=1.02)
ax.set_ylabel('Count')
ax.set_xlabel('City')
for i, count in enumerate(city_counts):
    plt.text(i, count + 1, str(count), ha='center', va='bottom')
plt.savefig('media/univariate_analysis/Top_10_Cities_Worldwide_Absolute_Billionaire_Distribution.png',
            bbox_inches='tight')
plt.show()

# %%
industry_counts = df['industries'] \
    .value_counts()
ax = industry_counts.plot(kind='bar',
                          figsize=(14, 4))
plt.title('Absolute Billionaires Industry Distribution Worldwide',
          fontsize=18,
          fontweight='bold',
          y=1.02)
ax.set_ylabel('Count')
ax.set_xlabel('Industry')
for i, count in enumerate(industry_counts):
    plt.text(i, count + 1, str(count), ha='center', va='bottom')
plt.savefig('media/univariate_analysis/Absolute_Billionaires_Industry_Distribution_Worldwide.png', bbox_inches='tight')
plt.show()

# %%
ax = df['age'].plot(kind='hist',
                    bins=20,
                    figsize=(8, 4))
plt.title('Ages Distribution of Billionaires Worldwide',
          fontsize=18,
          fontweight='bold',
          y=1.02)
ax.set_xlabel('Age')

plt.savefig('media/univariate_analysis/Ages_Distribution_of_Billionaires_Worldwide.png', bbox_inches='tight')
plt.show()

# %%
ax = df['gender'].value_counts() \
    .plot(kind='pie',
          autopct='%1.1f%%')
plt.title("Relative Gender Distribution of Billionaires Worldwide",
          fontweight='bold',
          fontsize=18,
          y=1.02)
ax.set_ylabel('')
plt.savefig('media/univariate_analysis/Relative_Gender_Distribution_of_Billionaires_Worldwide.png', bbox_inches='tight')
plt.show()

# %%
ax = df['wealth_source'].value_counts() \
    .plot(kind='pie',
          autopct='%1.1f%%')
plt.title("Relative Wealth-Source Distribution of Billionaires Worldwide",
          fontweight='bold',
          fontsize=18,
          y=1.02)
ax.set_ylabel('')
plt.savefig('media/univariate_analysis/Relative_Wealth_Source_Distribution_of_Billionaires_Worldwide.png',
            bbox_inches='tight')
plt.show()

# %% [markdown]
# # Feature Relationships - Multivariate analysis

# %% [markdown]
# ### Final Worth (M) vs. Age by Gender | Scatterplot

# %%
plt.figure(figsize=(16, 8))
sns.scatterplot(x='final_worth',
                y='age',
                hue='gender',
                palette={'M': 'blue', 'F': 'red'},
                data=df)
plt.title('Billionaires Final Worth (M) vs. Age by Gender Worldwide',
          fontweight='bold',
          fontsize=22,
          y=1.05)
plt.xlabel("Final Worth (M)")
plt.ylabel("Age")
plt.savefig('media/multivariate_analysis/Billionaires_Final_Worth_vs_Age_by_Gender_Worldwide.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Billionaires Count by Top Countries Worldwide and Wealth Source | Histogram

# %%
top_countries = df['country'].value_counts().head(20).index.tolist()
df_top_countries = df[df['country'].isin(top_countries)]
df_top_countries['country'].unique()
# Out:
# array(['France', 'United States', 'India', 'China', 'Canada', 'Germany',
#        'Switzerland', 'Hong Kong', 'Japan', 'United Kingdom', 'Australia',
#        'Russia', 'Sweden', 'Thailand', 'Singapore', 'Israel', 'Italy',
#        'Brazil', 'South Korea', 'Taiwan'], dtype=object)

# %%
df_top_countries
# Out:
#       rank  final_worth               person_name   age        country  \
# 0        1       211000  Bernard Arnault & family  74.0         France
# 1        2       180000                 Elon Musk  51.0  United States
# 2        3       114000                Jeff Bezos  59.0  United States
# 3        4       107000             Larry Ellison  78.0  United States
# 4        5       106000            Warren Buffett  92.0  United States
# ...    ...          ...                       ...   ...            ...
# 2632  2540         1000     Yi Xianzhong & family  63.0          China
# 2633  2540         1000                   Yu Rong  51.0          China
# 2634  2540         1000    Richard Yuengling, Jr.  80.0  United States
# 2635  2540         1000             Zhang Gongyun  60.0          China
# 2636  2540         1000    Zhang Guiping & family  71.0          China
#
#             city             industries       wealth_source status gender  \
# ...

# %%
plt.figure(figsize=(16, 10))
sns.histplot(
    data=df_top_countries,
    x="country",
    hue="wealth_source",
    edgecolor=".3",
    palette="hls",
    multiple='stack',
    linewidth=.5,
    stat='count'
)
plt.xticks(rotation=60)
plt.title("Billionaires Count by Top Countries Worldwide and Wealth Source",
          fontsize=24,
          fontweight='bold',
          y=1.01)
plt.ylabel("Billionaires count")
plt.xlabel("Country")
plt.savefig("media/multivariate_analysis/Billionaires_Count_by_Top_Countries_Worldwide_and_Wealth_Source.png",
            bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Billionaires per Industry, Age and Gender | Violin Plot

# %%
plt.figure(figsize=(20, 6))
sns.violinplot(data=df,
               x="industries",
               y="age",
               hue='gender',
               inner="quart",
               split=True)
plt.title("Relative Distribution of Billionaires by Industry, Age and Gender Worldwide",
          y=1.05,
          fontsize=24,
          fontweight="bold")
plt.ylabel("Age")
plt.xlabel("Industry")
plt.xticks(rotation=45)
plt.savefig(
    "media/multivariate_analysis/Relative_Distribution_of_Billionaires_by_Industry_Age_and_Gender_Worldwide.png",
    bbox_inches='tight')
plt.show()

# %% [markdown]
# ### International Billionaire Average Final Worth (M) by Global Region and Industry | Facet Grid

# %%
df['country'].unique()
# Out:
# array(['France', 'United States', 'Mexico', 'India', 'Spain', 'China',
#        'Canada', 'Germany', 'Switzerland', 'Belgium', 'Hong Kong',
#        'Austria', 'Japan', 'United Kingdom', 'Australia', 'Indonesia',
#        'United Arab Emirates', 'Russia', 'Chile', 'Monaco',
#        'Czech Republic', 'Sweden', nan, 'Thailand', 'Uzbekistan',
#        'Singapore', 'Nigeria', 'Israel', 'Italy', 'South Africa',
#        'Brazil', 'Malaysia', 'South Korea', 'New Zealand', 'Philippines',
#        'Taiwan', 'Norway', 'Egypt', 'Denmark', 'Eswatini (Swaziland)',
#        'Colombia', 'Netherlands', 'Poland', 'Bahamas', 'Ukraine',
#        'Cayman Islands', 'Greece', 'Turkey', 'Argentina', 'Georgia',
#        'Portugal', 'Kazakhstan', 'Algeria', 'Vietnam', 'Latvia',
#        'Finland', 'Bermuda', 'Luxembourg', 'British Virgin Islands',
#        'Cambodia', 'Lebanon', 'Oman', 'Ireland', 'Cyprus', 'Guernsey',
#        'Liechtenstein', 'Turks and Caicos Islands', 'Romania', 'Qatar',
# ...

# %%
country_to_global_region_dict = {
    'France': 'West Europe',
    'United States': 'North America',
    'Mexico': 'North America',
    'India': 'Asia',
    'Spain': 'West Europe',
    'China': 'Asia',
    'Canada': 'North America',
    'Germany': 'West Europe',
    'Switzerland': 'West Europe',
    'Belgium': 'West Europe',
    'Hong Kong': 'Asia',
    'Austria': 'West Europe',
    'Japan': 'Asia',
    'United Kingdom': 'West Europe',
    'Australia': 'Oceania',
    'Indonesia': 'Asia',
    'United Arab Emirates': 'Asia',
    'Russia': 'East Europe',
    'Chile': 'South America',
    'Monaco': 'West Europe',
    'Czech Republic': 'East Europe',
    'Sweden': 'West Europe',
    'Thailand': 'Asia',
    'Uzbekistan': 'Asia',
    'Singapore': 'Asia',
    'Nigeria': 'Africa',
    'Israel': 'Asia',
    'Italy': 'West Europe',
    'South Africa': 'Africa',
    'Brazil': 'South America',
    'Malaysia': 'Asia',
    'South Korea': 'Asia',
    'New Zealand': 'Oceania',
    'Philippines': 'Asia',
    'Taiwan': 'Asia',
    'Norway': 'West Europe',
    'Egypt': 'Africa',
    'Denmark': 'West Europe',
    'Eswatini (Swaziland)': 'Africa',
    'Colombia': 'South America',
    'Netherlands': 'West Europe',
    'Poland': 'East Europe',
    'Bahamas': 'North America',
    'Ukraine': 'East Europe',
    'Cayman Islands': 'North America',
    'Greece': 'West Europe',
    'Turkey': 'Asia',
    'Argentina': 'South America',
    'Georgia': 'East Europe',
    'Portugal': 'West Europe',
    'Kazakhstan': 'Asia',
    'Algeria': 'Africa',
    'Vietnam': 'Asia',
    'Latvia': 'East Europe',
    'Finland': 'West Europe',
    'Bermuda': 'North America',
    'Luxembourg': 'West Europe',
    'British Virgin Islands': 'North America',
    'Cambodia': 'Asia',
    'Lebanon': 'Asia',
    'Oman': 'Asia',
    'Ireland': 'West Europe',
    'Cyprus': 'Asia',
    'Guernsey': 'West Europe',
    'Liechtenstein': 'West Europe',
    'Turks and Caicos Islands': 'North America',
    'Romania': 'East Europe',
    'Qatar': 'Asia',
    'Uruguay': 'South America',
    'Nepal': 'Asia',
    'Slovakia': 'East Europe',
    'Morocco': 'Africa',
    'Hungary': 'East Europe',
    'Tanzania': 'Africa',
    'Bahrain': 'Asia',
    'Peru': 'South America',
    'Andorra': 'West Europe',
    'Armenia': 'East Europe',
    'NaN': 'Unknown'
}

# %%
df['global_region'] = df['country'].replace(country_to_global_region_dict)
df.query('country == global_region')
# Out:
# Empty DataFrame
# Columns: [rank, final_worth, person_name, age, country, city, industries, wealth_source, status, gender, life_expectancy_country, gross_tertiary_education_enrollment_country, gross_primary_education_enrollment_country, gdp_country_in_dollars, total_tax_rate_country, population_country, global_region]
# Index: []

# %%
avg_final_worth_per_global_region = df.groupby(['industries', 'global_region'])['final_worth'].mean().reset_index()
avg_final_worth_per_global_region
# Out:
#                     industries  global_region   final_worth
# 0                   Automotive           Asia   4555.555556
# 1                   Automotive  North America  18825.000000
# 2                   Automotive    West Europe   6442.857143
# 3   Construction & Engineering         Africa   7400.000000
# 4   Construction & Engineering           Asia   1876.923077
# ..                         ...            ...           ...
# 95                     Telecom           Asia   4230.769231
# 96                     Telecom    East Europe   1700.000000
# 97                     Telecom  North America  16028.571429
# 98                     Telecom        Oceania   1500.000000
# 99                     Telecom    West Europe   3385.714286
#
# [100 rows x 3 columns]

# %%
avg_final_worth_per_global_region.query('industries == "Technology" and global_region == "South America"')
# Out:
#     industries  global_region  final_worth
# 92  Technology  South America       4900.0

# %%
df.query('industries == "Technology"')
# Out:
#       rank  final_worth          person_name   age        country  \
# 2        3       114000           Jeff Bezos  59.0  United States
# 3        4       107000        Larry Ellison  78.0  United States
# 5        6       104000           Bill Gates  67.0  United States
# 9       10        80700        Steve Ballmer  67.0  United States
# 11      12        79200           Larry Page  50.0  United States
# ...    ...          ...                  ...   ...            ...
# 2598  2540         1000  Lu Yonghua & family  59.0          China
# 2600  2540         1000        Apoorva Mehta  36.0  United States
# 2611  2540         1000         Neerja Sethi  68.0  United States
# 2612  2540         1000          Scott Smith  73.0  United States
# 2621  2540         1000       Shigefumi Wada  70.0          Japan
#
#                city  industries wealth_source status gender  \
# 2            Medina  Technology     Self-Made      D      M
# ...

# %%
# Erstellung von FacetGrids für jeden globalen Bereich
g = sns.FacetGrid(data=avg_final_worth_per_global_region,
                  col='global_region',
                  col_wrap=4,
                  height=4.5)
g.map(sns.barplot,
      'industries', 'final_worth',
      edgecolor=".3",
      order=avg_final_worth_per_global_region['industries'].unique(),
      palette='Set1')
g.set_xticklabels(rotation=45)
g.set_axis_labels('Industries', 'Average Final Worth (M)')

handles = [mpatches.Patch(color=color,
                          label=label) for color, label in
           zip(sns.color_palette('Set1', n_colors=18), avg_final_worth_per_global_region['industries'].unique())]

plt.legend(handles=handles, title='Industries', bbox_to_anchor=(1.4, 1.05), loc='upper left')

title = plt.suptitle("Billionaires Average Final Worth (M) by Global Region and Industry Worldwide",
                     y=1.05,
                     fontweight='bold',
                     fontsize=24,
                     )

file_name_4 = "OLD_Billionaires_Average_Final_Worth_by_Global_Region_and_Industry_Worldwide.png"
plt.savefig(os.path.join("data_analysis/02_EDA/media/", file_name_4), bbox_inches='tight')
plt.show()
# Out:
# C:\Users\benne\PycharmProjects\billionaires_statistics\venv\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\benne\PycharmProjects\billionaires_statistics\venv\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\benne\PycharmProjects\billionaires_statistics\venv\lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# ...

# %% [markdown]
# ### Worldwide Billionaire Correlations between Economic and Demographic Indicators | Heatmap

# %%
corr_df = df[['final_worth', 'life_expectancy_country', 'gross_primary_education_enrollment_country',
              'gross_tertiary_education_enrollment_country', 'gdp_country_in_dollars', 'total_tax_rate_country',
              'population_country']].dropna().corr()
corr_df
# Out:
#                                              final_worth  \
# final_worth                                     1.000000
# life_expectancy_country                         0.021738
# gross_primary_education_enrollment_country     -0.008940
# gross_tertiary_education_enrollment_country     0.066517
# gdp_country_in_dollars                          0.037330
# total_tax_rate_country                         -0.036062
# population_country                             -0.053409
#
#                                              life_expectancy_country  \
# final_worth                                                 0.021738
# life_expectancy_country                                     1.000000
# gross_primary_education_enrollment_country                 -0.306978
# gross_tertiary_education_enrollment_country                 0.523889
# gdp_country_in_dollars                                     -0.056670
# total_tax_rate_country                                     -0.268308
# ...

# %%
sns.heatmap(data=corr_df,
            annot=True,
            cmap='YlGnBu')
plt.title("Billionaires Correlations between Economic and Demographic Indicators Worldwide",
          y=1.05,
          fontweight='bold',
          fontsize=18)
plt.savefig(
    'media/multivariate_analysis/Billionaires_Correlations_between_Economic_and_Demographic_Indicators_Worldwide.png',
    bbox_inches='tight')
plt.show()
